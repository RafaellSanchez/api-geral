# %%
#notebook para consultas sql

# %%
import sqlite3

caminho_banco_dados = '/workspaces/api-geral/GEO/sql/bd_geo.db'
conn = sqlite3.connect(caminho_banco_dados)
cursor = conn.cursor()

# %%
cursor.execute("PRAGMA table_info(slvr_geo)")

# Recupere os resultados da consulta
colunas = cursor.fetchall()

# Imprima o nome das colunas
for coluna in colunas:
    print(coluna[1])
# Out:
# uuid
# id
# nome
# idMunicipio
# nomeMunicipio
# idMacro
# nomeMacroMunicipio
# idUf
# estado
# siglaUf
# idRegiao
# regiao
# siglaRegiao
# dtIgtao

# %%
query = 'select * from slvr_geo'

cursor.execute(query)

resultados = cursor.fetchall()

# Exibir os resultados
for linha in resultados:
    print(linha)
# Out:
# ('87da412f4c1b4ab49da76da6c6c539e9', 291790410, 'Abadia', 2917904, 'Jandaíra', 2904, 'Nordeste Baiano', 29, 'Bahia', 'BA', 2, 'Nordeste', 'NE', '2024-02-13')
# ('9929277f66164e9aa0f7f926b7c38c6a', 311350310, 'Abadia de Carbonita', 3113503, 'Carbonita', 3103, 'Jequitinhonha', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-02-13')
# ('74c9f1b9897840ffa5e612c0e7512741', 520005005, 'Abadia de Goiás', 5200050, 'Abadia de Goiás', 5203, 'Centro Goiano', 52, 'Goiás', 'GO', 5, 'Centro-Oeste', 'CO', '2024-02-13')
# ('620db37d619243ab9184b48d1f71fc25', 310010405, 'Abadia dos Dourados', 3100104, 'Abadia dos Dourados', 3105, 'Triângulo Mineiro/Alto Paranaíba', 31, 'Minas Gerais', 'MG', 3, 'Sudeste', 'SE', '2024-02-13')
# ('e08cda92fc4f42b4846d3cab2da4d29c', 520010005, 'Abadiânia', 5200100, 'Abadiânia', 5204, 'Leste Goiano', 52, 'Goiás', 'GO', 5, 'Centro-Oeste', 'CO', '2024-02-13')
# ...
