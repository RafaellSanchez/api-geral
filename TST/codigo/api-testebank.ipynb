# %%
import pandas as pd
import requests

# %%
url = 'https://opendata.api.bb.com.br/open-banking/channels/v1/banking-agents?page=1520&page-size=2'

response = requests.get(url)
dados = response.json()
# display(dados)

list_data = []

for resultado in dados['data']['brand']['companies']:
    nome = resultado['name']
    cnpj = resultado['cnpjNumber']
    contrato = resultado['contractors']
    
    print(f'nome: {nome}')
    print(f'cnpj: {cnpj}')
    print(f'contrato: {contrato}')
    
    for result in resultado['contractors']:
        contrato_nome = result['name']
        contrato_cnpj = result['cnpjNumber']
        contrato_bank = result['bankingAgents']
        
        print(f'contrato nome: {contrato_nome}')
        print(f'contrato cnpj: {contrato_cnpj}')
        print(f'contrato banco: {contrato_bank}')
        
        for cliente in result['bankingAgents']:
            identificacao = cliente['identification']
            corporacao  = cliente['identification']['corporationName']
            grupo = cliente['identification']['groupName']
            isUnderestablishment = cliente['identification']['isUnderestablishment']
            cnpjnumber = cliente['identification']['cnpjNumber']
            localizacao = cliente['locations']
            endereco = cliente['locations']
            
            print(f'identificacao: {identificacao}')
            print(f'corporacao: {corporacao}')
            print(f'grupo: {grupo}')
            print(f'Understablishment: {isUnderestablishment}')
            print(f'cnpjNumber: {cnpjnumber}')
            print(f'localizacao: {localizacao}')
            print(f'Endereco: {endereco}')
            
            for local in cliente['locations']:
                postal = local['postalAddress']
                ender = local['postalAddress']['address']
                enderIdentInfo = local['postalAddress']['additionalInfo']
                districtName = local['postalAddress']['districtName']
                townName = local['postalAddress']['townName']
                ibgeCode = local['postalAddress']['ibgeCode']
                postCode = local['postalAddress']['postCode']
                country = local['postalAddress']['country']
                countryCode = local['postalAddress']['countryCode']
                cordLat = local['postalAddress']['geographicCoordinates']['latitude']
                cordLongt = local['postalAddress']['geographicCoordinates']['longitude']
                texception = local['availability']['exception']
                telefone = local['phones']
                
                print(f'Endereco postal: {postal}')
                print(f'Endereco: {ender}')
                print(f'EnderecoInfo: {enderIdentInfo}')
                print(f'Nome do distrito: {districtName}')
                print(f'Nome cidade: {townName}')
                print(f'CodeIbge: {ibgeCode}')
                print(f'Codigo postal: {postCode}')
                print(f'Pais: {country}')
                print(f'Codigo Pais: {countryCode}')
                print('---------------------------')
                print(local)
                
                for dispo in local['availability']['standards']:
                    weekday = dispo['weekday']
                    opentime = dispo['openingTime']
                    closetime = dispo['closingTime']
                    print(f'semana: {weekday}')
                    print(f'open: {opentime}')
                    print(f'close: {closetime}')
                    


    
                list_data.append({
                    'nome':nome,
                    'cnpj':cnpj,
                    'contrato':contrato,
                    'contrato_nome': contrato_nome,
                    'contrato_cnpj': contrato_cnpj,
                    'contrato_bank': contrato_bank,
                    'identificacao': identificacao,
                    'corporacao': corporacao,
                    'grupo': grupo,
                    'isUnderestablishment': isUnderestablishment,
                    'cnpjnumber': cnpjnumber,
                    'localizacao': localizacao,
                    'endereco': endereco,
                    'postal': postal,
                    'ender': ender,
                    'enderIdentInfo': enderIdentInfo,
                    'districtName': districtName,
                    'townName': townName,
                    'ibgeCode': ibgeCode,
                    'postCode': postCode,
                    'country': country,
                    'countryCode': countryCode                   
                    
                })

# df = pd.DataFrame(list_data)
# display(df)
# Out:
# nome: Banco do Brasil S/A
# cnpj: 00000000000191
# contrato: [{'name': 'MUITOFACIL ARRECADACAO E RECEB', 'cnpjNumber': '02789417000100', 'bankingAgents': [{'identification': {'corporationName': 'DJS MEDICAMENTOS E PERFUMARIA LTDA.', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '18478365000191'}, 'locations': [{'postalAddress': {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}], 'services': [{'name': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_OUTRAS_ATIVIDADES_DECORRENTES_EXECUCAO_CONTRATOS_CONVENIOS_PRESTACAO_SERVICOS', 'code': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_EXECUCAO_CONTRATOS_CONVENIO', 'additionalInfo': 'NA'}]}, {'identification': {'corporationName': 'DROGARIA ESTILO SAUDE LTDA', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '33539633000121'}, 'locations': [{'postalAddress': {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}], 'services': [{'name': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_OUTRAS_ATIVIDADES_DECORRENTES_EXECUCAO_CONTRATOS_CONVENIOS_PRESTACAO_SERVICOS', 'code': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_EXECUCAO_CONTRATOS_CONVENIO', 'additionalInfo': 'NA'}, {'name': 'OUTRO', 'code': 'OUTROS', 'additionalInfo': 'NA'}]}]}]
# contrato nome: MUITOFACIL ARRECADACAO E RECEB
# contrato cnpj: 02789417000100
# contrato banco: [{'identification': {'corporationName': 'DJS MEDICAMENTOS E PERFUMARIA LTDA.', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '18478365000191'}, 'locations': [{'postalAddress': {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}], 'services': [{'name': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_OUTRAS_ATIVIDADES_DECORRENTES_EXECUCAO_CONTRATOS_CONVENIOS_PRESTACAO_SERVICOS', 'code': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_EXECUCAO_CONTRATOS_CONVENIO', 'additionalInfo': 'NA'}]}, {'identification': {'corporationName': 'DROGARIA ESTILO SAUDE LTDA', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '33539633000121'}, 'locations': [{'postalAddress': {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}], 'services': [{'name': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_OUTRAS_ATIVIDADES_DECORRENTES_EXECUCAO_CONTRATOS_CONVENIOS_PRESTACAO_SERVICOS', 'code': 'RECEBIMENTOS_PAGAMENTOS_QUALQUER_NATUREZA_EXECUCAO_CONTRATOS_CONVENIO', 'additionalInfo': 'NA'}, {'name': 'OUTRO', 'code': 'OUTROS', 'additionalInfo': 'NA'}]}]
# identificacao: {'corporationName': 'DJS MEDICAMENTOS E PERFUMARIA LTDA.', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '18478365000191'}
# corporacao: DJS MEDICAMENTOS E PERFUMARIA LTDA.
# grupo: MUITOFACIL ARRECADACAO E RECEB
# Understablishment: True
# cnpjNumber: 18478365000191
# localizacao: [{'postalAddress': {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}]
# Endereco: [{'postalAddress': {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}]
# Endereco postal: {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}
# Endereco: PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021
# EnderecoInfo: NA
# Nome do distrito: CENTRO
# Nome cidade: ARAGUAIANA
# CodeIbge: 0510100
# Codigo postal: 78685000
# Pais: BRASIL
# Codigo Pais: BRA
# ---------------------------
# {'postalAddress': {'address': 'PRESIDENTE VARGAS N 497 QUADRA 18 LOTE 021', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'ARAGUAIANA', 'ibgeCode': '0510100', 'countrySubDivision': 'MT', 'postCode': '78685000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-15.723890000', 'longitude': '-51.83522100'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}
# semana: SEGUNDA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: TERCA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: QUARTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: QUINTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: SEXTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# identificacao: {'corporationName': 'DROGARIA ESTILO SAUDE LTDA', 'groupName': 'MUITOFACIL ARRECADACAO E RECEB', 'isUnderestablishment': True, 'cnpjNumber': '33539633000121'}
# corporacao: DROGARIA ESTILO SAUDE LTDA
# grupo: MUITOFACIL ARRECADACAO E RECEB
# Understablishment: True
# cnpjNumber: 33539633000121
# localizacao: [{'postalAddress': {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}]
# Endereco: [{'postalAddress': {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}]
# Endereco postal: {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}
# Endereco: R MIGUEL CALADO BORBA 33
# EnderecoInfo: NA
# Nome do distrito: CENTRO
# Nome cidade: JUPI
# CodeIbge: 0260830
# Codigo postal: 55395000
# Pais: BRASIL
# Codigo Pais: BRA
# ---------------------------
# {'postalAddress': {'address': 'R MIGUEL CALADO BORBA 33', 'additionalInfo': 'NA', 'districtName': 'CENTRO', 'townName': 'JUPI', 'ibgeCode': '0260830', 'countrySubDivision': 'PE', 'postCode': '55395000', 'country': 'BRASIL', 'countryCode': 'BRA', 'geographicCoordinates': {'latitude': '-8.706400000', 'longitude': '-36.41740000'}}, 'availability': {'standards': [{'weekday': 'SEGUNDA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'TERCA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUARTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'QUINTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}, {'weekday': 'SEXTA_FEIRA', 'openingTime': '11:00:00Z', 'closingTime': '21:00:00Z'}], 'exception': 'Funcionamento somente em dias úteis', 'isPublicAccessAllowed': True}, 'phones': [{'type': 'FIXO', 'countryCallingCode': '0', 'areaCode': '00', 'number': '00000000'}]}
# semana: SEGUNDA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: TERCA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: QUARTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: QUINTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
# semana: SEXTA_FEIRA
# open: 11:00:00Z
# close: 21:00:00Z
