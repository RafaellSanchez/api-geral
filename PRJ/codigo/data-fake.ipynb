# %%
# %pip install Faker
# Out:
# Requirement already satisfied: Faker in /usr/local/python/3.10.13/lib/python3.10/site-packages (23.2.1)
# Requirement already satisfied: python-dateutil>=2.4 in /home/codespace/.local/lib/python3.10/site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from faker import Faker

# %%
# Crie uma instância do Faker
fake = Faker('pt_BR')
# Gere um nome fictício
nome = fake.name()
# Gere um endereço fictício
endereco = fake.address()
# Gere um número de telefone fictício
telefone = fake.phone_number()
# Gere uma data de nascimento fictícia
data_de_nascimento = fake.date_of_birth(minimum_age=18, maximum_age=65)
# Imprima os dados fictícios
print("Nome: ", nome)
print("Endereço: ", endereco)
print("Telefone: ", telefone)
print("Data de Nascimento: ", data_de_nascimento)
# Out:
# Nome:  Emanuella da Conceição
# Endereço:  Feira Nascimento
# Vila Aeroporto Jaraguá
# 82758-892 Ferreira / MT
# Telefone:  (081) 1580 8879
# Data de Nascimento:  1998-04-11

# %%
from faker import Faker  
fake = Faker('pt_BR')      

dados_list = []

for i in range(0, 10):
    nome = fake.name()
    pais = fake.country()
    endereco = fake.address()
    email = fake.email()
    numero_telefone = fake.phone_number()
    
    dados_list.append({
        'nome': nome,
        'email': email,
        'telefone': numero_telefone,
        'endereco': endereco,
        'pais': pais
    })

df = pd.DataFrame(dados_list)
display(df)
    # print(f'nome: {nome}')
    # print(f'pais: {pais}')
    # print(f'endereco: {endereco}')
    # print(f'email: {email}')
    
      
    # print('Name->', fake.name(), 
    #       'Country->', fake.country())
# Out:
#                        nome                            email  \
# 0         Mirella Rodrigues          renanmendes@example.com
# 1  Dra. Maria Cecília Sales         luigibarbosa@example.net
# 2           Eduardo da Mata               jrocha@example.org
# 3      Maria Luiza Nogueira               valves@example.com
# 4    Pedro Henrique Rezende  enzo-gabrielda-mata@example.net
# 5             Maria Cardoso        castrovicente@example.org
# 6           Helena da Cunha            sabrina91@example.net
# 7    Vitor Gabriel da Costa         ana-sophia70@example.net
# 8            Matheus da Luz           costamaria@example.org
# 9               Julia Gomes        calebeda-mata@example.com
#
#               telefone                                           endereco  \
# 0      (031) 6766 4502  Vila Ana Lívia Silveira\nBoa Vista\n56365-562 ...
# 1     +55 21 7686-6710  Fazenda Juliana Mendes, 732\nAlto Caiçaras\n23...
# 2      (031) 4196-4701  Campo Mendes, 2\nVila Bandeirantes\n43929-788 ...
# 3     +55 41 1179-5518  Alameda Cardoso, 8\nVila Copasa\n93284159 Nasc...
# 4      (051) 3033-9434  Vale Sophie Costa, 2\nVila Inestan\n21095718 C...
# 5         84 8087-3469  Praça Farias, 18\nVila Real 2ª Seção\n94053-98...
# 6  +55 (011) 1759-1659  Ladeira Azevedo, 42\nApolonia\n22669-913 Lima ...
# 7         41 3202 9424  Rodovia de Viana\nSilveira\n31938-789 Gonçalve...
# 8     +55 41 6187-4254  Largo Rafaela da Luz, 948\nSão Francisco\n8346...
# 9      (041) 3223-3039  Jardim Nogueira, 367\nTúnel De Ibirité\n93844-...
#
#                           pais
# 0                      Camboja
# 1  Ashmore and Cartier Islands
# 2                     Bulgária
# 3                      Senegal
# 4                 Bielorrússia
# 5                        Palau
# 6                    Filipinas
# 7               Nova Caledónia
# 8                    Nicarágua
# 9                       Grécia
